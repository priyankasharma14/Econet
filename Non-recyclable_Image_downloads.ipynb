# %%
! git clone https://github.com/Joeclinton1/google-images-download.git
# Out:
# Cloning into 'google-images-download'...
# remote: Enumerating objects: 719, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 719 (delta 32), reused 27 (delta 16), pack-reused 666
# Receiving objects: 100% (719/719), 322.07 KiB | 11.93 MiB/s, done.
# Resolving deltas: 100% (422/422), done.

# %%
cd google-images-download
# Out:
# /content/google-images-download

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install selenium
# Out:
# ...
#      |████████████████████████████████| 954 kB 23.4 MB/s
# ...
#      |████████████████████████████████| 138 kB 61.8 MB/s
# ...
#      |████████████████████████████████| 356 kB 47.4 MB/s
# ...
#      |████████████████████████████████| 55 kB 4.4 MB/s
# ...
#      |████████████████████████████████| 3.5 MB 37.3 MB/s
# ...
#      |████████████████████████████████| 54 kB 3.6 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# requests 2.23.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 1.26.7 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# ...

# %%
# !apt install chromium-chromedriver -q
# !pip install google_images_download selenium -q
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-codecs-ffmpeg-extra
# Suggested packages:
#   webaccounts-chromium-extension unity-chromium-extension
# The following NEW packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-chromedriver
#   chromium-codecs-ffmpeg-extra
# 0 upgraded, 4 newly installed, 0 to remove and 37 not upgraded.
# Need to get 95.4 MB of archives.
# After this operation, 323 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-codecs-ffmpeg-extra amd64 94.0.4606.71-0ubuntu0.18.04.1 [1,136 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-browser amd64 94.0.4606.71-0ubuntu0.18.04.1 [85.1 MB]
# ...

# %%
import sys
from selenium import webdriver

# %%
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
sys.path.insert(0,'/usr/lib/chromium-browser/chromedriver')

# set options to be headless, ..
options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
# Out:
# cp: '/usr/lib/chromium-browser/chromedriver' and '/usr/bin/chromedriver' are the same file

# %%
# Shredded paper
from google_images_download import google_images_download   #importing the library

response = google_images_download.googleimagesdownload()   #class instantiation

arguments = {"keywords":"shredded paper","limit":100,
             "print_urls":True,
              "chromedriver": "/usr/bin/chromedriver"
             }   #creating list of arguments
paths = response.download(arguments)   #passing the arguments to the function
print(paths)   #printing absolute paths of the downloaded images
# Out:
# Item no.: 1 --> Item name = shredded paper
# Evaluating...
# Starting Download...
# Image URL: https://static.nashvillewraps.com/images/sku/SP10WH-XLARGE.jpg
# Completed Image ====> 1.sp10wh-xlarge.jpg
# Image URL: https://www.treehugger.com/thmb/ofg-rRO_o9qTdPc-NLzcT0_m7h0=/865x649/smart/filters:no_upscale()/__opt__aboutcom__coeus__resources__content_migration__mnn__images__2018__08__shredded_paper-eeae4195fddd4d4389afb8fdeca5f117.jpg
# Completed Image ====> 2.__opt__aboutcom__coeus__resources__content_migration__mnn__images__2018__08__shredded_paper-eeae4195fddd4d4389afb8fdeca5f117.jpg
# Image URL: https://www.shrednations.com/wp-content/uploads/shredded-paper-reuse-recycle-advantage.jpg
# Completed Image ====> 3.shredded-paper-reuse-recycle-advantage.jpg
# Image URL: https://images.fineartamerica.com/images-medium-large/1-shredded-paper-blink-images.jpg
# Completed Image ====> 4.1-shredded-paper-blink-images.jpg
# ...

# %% [markdown]
# 14 were deleted

# %%
import shutil
shutil.move("/content/google-images-download/downloads/shredded paper", "/content/drive/Shareddrives/OPIM 5509_Intro to Deep Learning_Group 3 /data")
# Out:
# '/content/drive/Shareddrives/OPIM 5509_Intro to Deep Learning_Group 3 /data/shredded paper'

# %%
# Plastic bags
from google_images_download import google_images_download   #importing the library

response = google_images_download.googleimagesdownload()   #class instantiation

arguments = {"keywords":"plastic bags","limit":100,
             "print_urls":True,
              "chromedriver": "/usr/bin/chromedriver"
             }   #creating list of arguments
paths = response.download(arguments)   #passing the arguments to the function
print(paths)   #printing absolute paths of the downloaded images
# Out:
# Item no.: 1 --> Item name = plastic bags
# Evaluating...
# Starting Download...
# Image URL: https://i.guim.co.uk/img/media/88e31ffdbd4f105b04e4a7a15164ee5b93fca74d/0_89_3500_2101/master/3500.jpg?width=1200&height=900&quality=85&auto=format&fit=crop&s=6e6b76e52be5c3081c9a31250e1faef4
# Completed Image ====> 1.3500.jpg
# Image URL: https://acs-h.assetsadobe.com/is/image//content/dam/cen/92/37/09237-cover-plasticbag.jpg/?$responsive$&wid=700&qlt=90,0&resMode=sharp2
# Completed Image ====> 2..jpg
# Image URL: https://whyy.org/wp-content/uploads/2018/08/bigstock-Multiple-Plastic-Shopping-Bags-239117521.jpg
# Completed Image ====> 3.bigstock-multiple-plastic-shopping-bags-239117521.jpg
# Image URL: https://thumbor.forbes.com/thumbor/960x0/https%3A%2F%2Fspecials-images.forbesimg.com%2Fimageserve%2F5f91cb4c568059015a888165%2FPlastic-bags-background--environmental-hazard%2F960x0.jpg%3Ffit%3Dscale
# ...

# %%
import shutil
shutil.move("/content/google-images-download/downloads/plastic bags", "/content/drive/Shareddrives/OPIM 5509_Intro to Deep Learning_Group 3 /data")
# Out:
# '/content/drive/Shareddrives/OPIM 5509_Intro to Deep Learning_Group 3 /data/plastic bags'

# %% [markdown]
# 20 were deleted

# %%
# clothes
from google_images_download import google_images_download   #importing the library

response = google_images_download.googleimagesdownload()   #class instantiation

arguments = {"keywords":"used clothes","limit":100,
             "print_urls":True,
              "chromedriver": "/usr/bin/chromedriver"
             }   #creating list of arguments
paths = response.download(arguments)   #passing the arguments to the function
print(paths)   #printing absolute paths of the downloaded images
# Out:
# Item no.: 1 --> Item name = used clothes
# Evaluating...
# Starting Download...
# Image URL: https://greenthatlife.com/wp-content/uploads/2020/11/IMG_0178.jpeg
# Completed Image ====> 1.img_0178.jpeg
# Image URL: https://www.aeclothing.net/wp-content/uploads/2017/07/used-womens-clothing.jpg
# Completed Image ====> 2.used-womens-clothing.jpg
# Image URL: https://thumbs.dreamstime.com/b/pile-old-used-clothes-isolated-white-163045020.jpg
# Completed Image ====> 3.pile-old-used-clothes-isolated-white-163045020.jpg
# Image URL: https://media.istockphoto.com/photos/second-hand-clothing-shop-used-clothes-hanging-in-hanger-in-a-rack-picture-id832186650?k=20&m=832186650&s=170667a&w=0&h=hNVfgiM6u4Yls_CUtTpvw0yQj4Chm7Rxv7k4jaLFbdk=
# Completed Image ====> 4.second-hand-clothing-shop-used-clothes-hanging-in-hanger-in-a-rack-picture-id832186650.jpg
# Image URL: https://www.payoff.com/life/wp-content/uploads/2015/03/2016-03_-how-to-sell-old-clothes-for-money.jpg?x20664
# ...

# %%
import shutil
shutil.move("/content/google-images-download/downloads/used clothes", "/content/drive/Shareddrives/OPIM 5509_Intro to Deep Learning_Group 3 /data")
# Out:
# '/content/drive/Shareddrives/OPIM 5509_Intro to Deep Learning_Group 3 /data/used clothes'

# %% [markdown]
# only 50 items were usable (200 so far)

# %%
# diapers
from google_images_download import google_images_download   #importing the library

response = google_images_download.googleimagesdownload()   #class instantiation

arguments = {"keywords":"used diapers","limit":100,
             "print_urls":True,
              "chromedriver": "/usr/bin/chromedriver"
             }   #creating list of arguments
paths = response.download(arguments)   #passing the arguments to the function
print(paths)   #printing absolute paths of the downloaded images
# Out:
# Item no.: 1 --> Item name = used diapers
# Evaluating...
# Starting Download...
# Image URL: https://www.abc.net.au/news/image/10925258-3x2-940x627.jpg
# Completed Image ====> 1.10925258-3x2-940x627.jpg
# Image URL: https://media.istockphoto.com/photos/disposable-dirty-diaper-picture-id121352105?k=20&m=121352105&s=612x612&w=0&h=w03oMo9Cap8zs_fqHtfbDnpEnjh4flFRi4oFyZSEqqU=
# Completed Image ====> 2.disposable-dirty-diaper-picture-id121352105.jpg
# Image URL: https://scitechdaily.com/images/Used-Diapers.jpg
# Completed Image ====> 3.used-diapers.jpg
# Image URL: https://image.shutterstock.com/image-photo/used-disposable-diapers-closeup-isolated-260nw-606490760.jpg
# Completed Image ====> 4.used-disposable-diapers-closeup-isolated-260nw-606490760.jpg
# Image URL: https://pix11.com/wp-content/uploads/sites/25/2020/01/poster_ed0ba2f62d014fdfa02b645eb80cc2dd-2.jpeg?w=1920&h=1080&crop=1
# Completed Image ====> 5.poster_ed0ba2f62d014fdfa02b645eb80cc2dd-2.jpeg
# ...

# %%
shutil.move("/content/google-images-download/downloads/used diapers", "/content/drive/Shareddrives/OPIM 5509_Intro to Deep Learning_Group 3 /data")
# Out:
# '/content/drive/Shareddrives/OPIM 5509_Intro to Deep Learning_Group 3 /data/used diapers'

# %% [markdown]
# 50 were used (should have scraped only 50)

# %%
# hanger
from google_images_download import google_images_download   #importing the library

response = google_images_download.googleimagesdownload()   #class instantiation

arguments = {"keywords":"hanger","limit":75,
             "print_urls":True,
              "chromedriver": "/usr/bin/chromedriver"
             }   #creating list of arguments
paths = response.download(arguments)   #passing the arguments to the function
print(paths)   #printing absolute paths of the downloaded images
# Out:
# Item no.: 1 --> Item name = hanger
# Evaluating...
# Starting Download...
# Image URL: https://www.ikea.com/us/en/images/products/bumerang-coat-hanger-natural__0944470_pe797277_s5.jpg
# Completed Image ====> 1.bumerang-coat-hanger-natural__0944470_pe797277_s5.jpg.webp
# Image URL: https://media.fds.fi/product_image/800/624Hay_iso.jpg
# Completed Image ====> 2.624hay_iso.jpg
# Image URL: https://www.ikea.com/us/en/images/products/bumerang-hanger-natural__0710666_pe727700_s5.jpg
# Completed Image ====> 3.bumerang-hanger-natural__0710666_pe727700_s5.jpg.webp
# Image URL: https://m.media-amazon.com/images/I/61PC+CABS9L._AC_SL1500_.jpg
# Completed Image ====> 4.61pc+cabs9l._ac_sl1500_.jpg
# Image URL: https://www.containerstore.com/catalogimages/403737/10082066-serene-matte-metal-suit-han.jpg
# Completed Image ====> 5.10082066-serene-matte-metal-suit-han.jpg
# ...

# %%
shutil.move("/content/google-images-download/downloads/hanger", "/content/drive/Shareddrives/OPIM 5509_Intro to Deep Learning_Group 3 /data")
# Out:
# '/content/drive/Shareddrives/OPIM 5509_Intro to Deep Learning_Group 3 /data/hanger'

# %% [markdown]
# 17 deleted (300 so far)

# %%
# trash wrappers
from google_images_download import google_images_download   #importing the library

response = google_images_download.googleimagesdownload()   #class instantiation

arguments = {"keywords":"trash wrappers","limit":50,
             "print_urls":True,
              "chromedriver": "/usr/bin/chromedriver"
             }   #creating list of arguments
paths = response.download(arguments)   #passing the arguments to the function
print(paths)   #printing absolute paths of the downloaded images
# Out:
# Item no.: 1 --> Item name = trash wrappers
# Evaluating...
# Starting Download...
# Image URL: https://mygreenmontgomery.org/wp-content/uploads/2016/03/Wrappers-e1542402443947.jpg
# Completed Image ====> 1.wrappers-e1542402443947.jpg
# Image URL: https://www.candyclub.com/blog/wp-content/uploads/2019/07/candywrapper_3.png
# Completed Image ====> 2.candywrapper_3.png
# Image URL: https://c8.alamy.com/comp/F279W7/a-trash-can-overflowing-with-empty-drinks-containers-and-food-wrappers-F279W7.jpg
# Completed Image ====> 3.a-trash-can-overflowing-with-empty-drinks-containers-and-food-wrappers-f279w7.jpg
# Image URL: https://image.shutterstock.com/image-photo/paper-wrapper-trash-isolated-on-260nw-1010583352.jpg
# Completed Image ====> 4.paper-wrapper-trash-isolated-on-260nw-1010583352.jpg
# ...

# %%
shutil.move("/content/google-images-download/downloads/trash wrappers", "/content/drive/Shareddrives/OPIM 5509_Intro to Deep Learning_Group 3 /data")
# Out:
# '/content/drive/Shareddrives/OPIM 5509_Intro to Deep Learning_Group 3 /data/trash wrappers'

# %% [markdown]
# 15 deleted (335 so far)

# %%
# metal parts
from google_images_download import google_images_download   #importing the library

response = google_images_download.googleimagesdownload()   #class instantiation

arguments = {"keywords":"metal parts","limit":100,
             "print_urls":True,
              "chromedriver": "/usr/bin/chromedriver"
             }   #creating list of arguments
paths = response.download(arguments)   #passing the arguments to the function
print(paths)   #printing absolute paths of the downloaded images
# Out:
# Item no.: 1 --> Item name = metal parts
# Evaluating...
# Starting Download...
# Image URL: https://www.protocase.com/products/sheet-metal-parts/img/turning2.png
# Completed Image ====> 1.turning2.png
# Image URL: https://www.powderedmetalparts.com/wp-content/uploads/2016/03/PowderedMetalParts1.jpg
# Completed Image ====> 2.powderedmetalparts1.jpg
# Image URL: http://www.parcoinc.com/images/custom-metal-2.jpg
# Completed Image ====> 3.custom-metal-2.jpg
# Image URL: https://www.protocase.com/products/sheet-metal-parts/img/finished-part-04.jpg
# Completed Image ====> 4.finished-part-04.jpg
# Image URL: https://cdn.shopify.com/s/files/1/0030/7372/articles/IMG_1604_2048x.progressive.JPG?v=1508520265
# Completed Image ====> 5.img_1604_2048x.progressive.jpg
# ...

# %%
shutil.move("/content/google-images-download/downloads/metal parts", "/content/drive/Shareddrives/OPIM 5509_Intro to Deep Learning_Group 3 /data")
# Out:
# '/content/drive/Shareddrives/OPIM 5509_Intro to Deep Learning_Group 3 /data/metal parts'

# %% [markdown]
# about 430 in total
