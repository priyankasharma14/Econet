# %%
! git clone https://github.com/Joeclinton1/google-images-download.git
# Out:
# Cloning into 'google-images-download'...
# remote: Enumerating objects: 719, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 719 (delta 32), reused 27 (delta 16), pack-reused 666
# Receiving objects: 100% (719/719), 322.07 KiB | 7.49 MiB/s, done.
# Resolving deltas: 100% (422/422), done.

# %%
cd google-images-download
# Out:
# /content/google-images-download

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install selenium
# Out:
# ...
#      |████████████████████████████████| 954 kB 5.1 MB/s
# ...
#      |████████████████████████████████| 138 kB 54.7 MB/s
# ...
#      |████████████████████████████████| 356 kB 40.6 MB/s
# ...
#      |████████████████████████████████| 55 kB 3.0 MB/s
# ...
#      |████████████████████████████████| 3.5 MB 31.6 MB/s
# ...
#      |████████████████████████████████| 54 kB 3.3 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# requests 2.23.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 1.26.7 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# ...

# %%
# !apt install chromium-chromedriver -q
# !pip install google_images_download selenium -q
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-codecs-ffmpeg-extra
# Suggested packages:
#   webaccounts-chromium-extension unity-chromium-extension
# The following NEW packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-chromedriver
#   chromium-codecs-ffmpeg-extra
# 0 upgraded, 4 newly installed, 0 to remove and 37 not upgraded.
# Need to get 95.4 MB of archives.
# After this operation, 323 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-codecs-ffmpeg-extra amd64 94.0.4606.71-0ubuntu0.18.04.1 [1,136 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-browser amd64 94.0.4606.71-0ubuntu0.18.04.1 [85.1 MB]
# ...

# %%
import sys
from selenium import webdriver

# %%
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
sys.path.insert(0,'/usr/lib/chromium-browser/chromedriver')

# set options to be headless, ..
options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
# Out:
# cp: '/usr/lib/chromium-browser/chromedriver' and '/usr/bin/chromedriver' are the same file

# %%
# Food scraps
from google_images_download import google_images_download   #importing the library

response = google_images_download.googleimagesdownload()   #class instantiation

arguments = {"keywords":"Food scrap","limit":500,
             "print_urls":True,
              "chromedriver": "/usr/bin/chromedriver"
             }   #creating list of arguments
paths = response.download(arguments)   #passing the arguments to the function
print(paths)   #printing absolute paths of the downloaded images
# Out:
# Item no.: 1 --> Item name = Food scrap
# Evaluating...
# Getting you a lot of images. This may take a few moments...
# Reached end of Page.
# Starting Download...
# Image URL: https://bokashiliving.com/wp-content/uploads/2016/10/Composting-1.jpg
# Completed Image ====> 1.composting-1.jpg
# Image URL: https://assets.nrdc.org/sites/default/files/styles/full_content--retina/public/media-uploads/foodscraprecyclinglandscapeassessmentguide_1020211970_1800x1200.jpg?itok=DK30y8Mb
# Completed Image ====> 2.foodscraprecyclinglandscapeassessmentguide_1020211970_1800x1200.jpg
# Image URL: https://live-production.wcms.abc-cdn.net.au/b01d897fd387595e6b14fe4a17575d8d?impolicy=wcms_crop_resize&cropH=1194&cropW=2121&xPos=0&yPos=36&width=862&height=485
# Completed Image ====> 3.b01d897fd387595e6b14fe4a17575d8d.webp
# Image URL: https://grist.org/wp-content/uploads/2016/11/food-scraps-shutterstock-c.jpg
# Completed Image ====> 4.food-scraps-shutterstock-c.jpg
# ...

# %%
import shutil
shutil.move("/content/google-images-download/downloads/Food scrap", "/content/drive/Shareddrives/OPIM 5509_Intro to Deep Learning_Group 3 /data/food scrap")
# Out:
# '/content/drive/Shareddrives/OPIM 5509_Intro to Deep Learning_Group 3 /data/food scrap/Food scrap'

# %% [markdown]
# The food scrap image download showed a lot of flaws: duplicate images, images of garbage cans, people, drawings etc... all those are not relevant for our model and needed to be manually deleted.<br>
# We noticed that mostly the first 50 images were most relevant.<br>
# We will scrap other images within that category using different keywords

# %%
# Fruit peels
from google_images_download import google_images_download   #importing the library

response = google_images_download.googleimagesdownload()   #class instantiation

arguments = {"keywords":"Fruit peels","limit":100,
             "print_urls":True,
              "chromedriver": "/usr/bin/chromedriver"
             }   #creating list of arguments
paths = response.download(arguments)   #passing the arguments to the function
print(paths)   #printing absolute paths of the downloaded images
# Out:
# Item no.: 1 --> Item name = Fruit peels
# Evaluating...
# Starting Download...
# Image URL: https://static.toiimg.com/photo/73331141.cms
# Completed Image ====> 1.73331141.cms.jpg
# Image URL: https://i0.wp.com/bioplasticsnews.com/wp-content/uploads/2019/12/fruit-peel-biodegradation.jpg?fit=1128%2C600&ssl=1
# Completed Image ====> 2.fruit-peel-biodegradation.jpg
# Image URL: https://static.toiimg.com/photo/65231303.cms
# Completed Image ====> 3.65231303.cms.jpg
# Image URL: https://c8.alamy.com/comp/MF4MYA/fruit-peels-in-a-recyclable-and-biodegradable-bag-MF4MYA.jpg
# Completed Image ====> 4.fruit-peels-in-a-recyclable-and-biodegradable-bag-mf4mya.jpg
# Image URL: https://trashmagination.com/wp-content/uploads/2019/04/julia-kouzenkov-1360704-unsplash-e1555030727197-700x400.jpg
# Completed Image ====> 5.julia-kouzenkov-1360704-unsplash-e1555030727197-700x400.jpg
# Image URL: https://vaya.in/news/wp-content/uploads/2019/07/left-over-fruit-peels-1280x720.jpg
# ...

# %%
import shutil
shutil.move("/content/google-images-download/downloads/Fruit peels", "/content/drive/Shareddrives/OPIM 5509_Intro to Deep Learning_Group 3 /data/fruit peels")
# Out:
# '/content/drive/Shareddrives/OPIM 5509_Intro to Deep Learning_Group 3 /data/fruit peels/Fruit peels'

# %% [markdown]
# Those keywords were more efficient as only 3 pictures were irrelevant (graphs and drawings)

# %%
# greasy pizza box
from google_images_download import google_images_download   #importing the library

response = google_images_download.googleimagesdownload()   #class instantiation

arguments = {"keywords":"grease pizza box","limit":50,
             "print_urls":True,
              "chromedriver": "/usr/bin/chromedriver"
             }   #creating list of arguments
paths = response.download(arguments)   #passing the arguments to the function
print(paths)   #printing absolute paths of the downloaded images
# Out:
# Item no.: 1 --> Item name = grease pizza box
# Evaluating...
# Starting Download...
# Image URL: https://mydisposal.com/wp-content/uploads/2019/02/Pizza_Box_Recycling.jpg
# Completed Image ====> 1.pizza_box_recycling.jpg
# Image URL: https://ssrcoop.info/wp-content/uploads/2020/08/PizzaBox-greasy.jpg
# Completed Image ====> 2.pizzabox-greasy.jpg
# Image URL: https://production-500eco.s3.amazonaws.com/uploads/photo/image/188/pizza-box.jpg
# Completed Image ====> 3.pizza-box.jpg
# Image URL: https://www.sbs.com.au/topics/sites/sbs.com.au.topics/files/styles/full/public/gettyimages-500612190.jpg?itok=qamchJtr&mtime=1472451759
# Completed Image ====> 4.gettyimages-500612190.jpg
# Image URL: https://www.acedisposal.com/wp-content/uploads/Pizza.jpg
# Completed Image ====> 5.pizza.jpg
# Image URL: https://recyclecoach.com/wp-content/uploads/2021/04/How_bad_are_greasy_pizza.jpeg
# Completed Image ====> 6.how_bad_are_greasy_pizza.jpeg
# ...

# %%
import shutil
shutil.move("/content/google-images-download/downloads/grease pizza box", "/content/drive/Shareddrives/OPIM 5509_Intro to Deep Learning_Group 3 /data")
# Out:
# '/content/drive/Shareddrives/OPIM 5509_Intro to Deep Learning_Group 3 /data/grease pizza box'

# %% [markdown]
# This part is more tricky as it will contain a lot of images of food (pizza). however, this is a critical subcategory to help efficient recycling. 18 of the 50 images were deleted (pizza present on the picture)

# %%
# moldy food
from google_images_download import google_images_download   #importing the library

response = google_images_download.googleimagesdownload()   #class instantiation

arguments = {"keywords":"mold food","limit":200,
             "print_urls":True,
              "chromedriver": "/usr/bin/chromedriver"
             }   #creating list of arguments
paths = response.download(arguments)   #passing the arguments to the function
print(paths)   #printing absolute paths of the downloaded images
# Out:
# Item no.: 1 --> Item name = mold food
# Evaluating...
# Getting you a lot of images. This may take a few moments...
# Reached end of Page.
# Starting Download...
# Image URL: https://cdn.vox-cdn.com/thumbor/Oc7TGjveqmUnec2lhxZhbL_wF_0=/0x0:5312x2988/1200x800/filters:focal(2232x1070:3080x1918)/cdn.vox-cdn.com/uploads/chorus_image/image/67056409/GettyImages_758591313.0.jpg
# Completed Image ====> 1.gettyimages_758591313.0.jpg
# Image URL: https://cdn.mos.cms.futurecdn.net/S7mQ2XopkNriYAMLuS48j9.jpg
# Completed Image ====> 2.s7mq2xopknriyamlus48j9.jpg
# Image URL: https://imagesvc.meredithcorp.io/v3/mm/image?q=85&c=sc&poi=face&url=https%3A%2F%2Fimg1.cookinglight.timeinc.net%2Fsites%2Fdefault%2Ffiles%2Fstyles%2F4_3_horizontal_-_1200x900%2Fpublic%2Fcardiologist-recommended-bread-ft-blog0517.jpg%3Fitok%3Dq6WbWbY8
# Completed Image ====> 3.image.jpg
# ...

# %%
shutil.move("/content/google-images-download/downloads/mold food", "/content/drive/Shareddrives/OPIM 5509_Intro to Deep Learning_Group 3 /data")
# Out:
# '/content/drive/Shareddrives/OPIM 5509_Intro to Deep Learning_Group 3 /data/mold food'

# %% [markdown]
# Only 32 images deleted. Although some do not exactly fit the category, they are still food items which will work on our compostable category.
